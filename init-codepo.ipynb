# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm
tqdm.pandas()
pd.set_option('display.max_columns', 500)

sns.set_theme()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # pre-processing codepo

# %%
from glob import glob

# %%
cs = glob("./codepo_gb/Data/CSV/*.csv")

# %%
_c = cs[0]

# %%
pd.read_csv(_c, header=None)
# Out:
#               0   1       2       3          4   5          6   7          8  \
# 0      AB10 1AB  10  394235  806529  S92000003 NaN  S08000020 NaN  S12000033
# 1      AB10 1AF  10  394235  806529  S92000003 NaN  S08000020 NaN  S12000033
# 2      AB10 1AG  10  394230  806469  S92000003 NaN  S08000020 NaN  S12000033
# 3      AB10 1AH  10  394235  806529  S92000003 NaN  S08000020 NaN  S12000033
# 4      AB10 1AL  10  394296  806581  S92000003 NaN  S08000020 NaN  S12000033
# ...         ...  ..     ...     ...        ...  ..        ...  ..        ...
# 17335  AB56 5YX  10  348775  862803  S92000003 NaN  S08000020 NaN  S12000020
# 17336  AB56 9AG  10  342784  865670  S92000003 NaN  S08000020 NaN  S12000020
# 17337  AB99 8AA  10  394406  802269  S92000003 NaN  S08000020 NaN  S12000033
# 17338  AB99 8AB  10  394406  802269  S92000003 NaN  S08000020 NaN  S12000033
# 17339  AB99 8AF  10  394406  802269  S92000003 NaN  S08000020 NaN  S12000033
#
#                9
# 0      S13002842
# ...

# %% [markdown]
# # seek alternative data

# %%
ukpc = pd.read_csv("ukpostcodes.csv")

# %%
ukpc = ukpc.set_index('id')

# %%
ukpc.to_feather("ukpc.feather")

# %%
ukpc
# Out:
#          postcode   latitude  longitude
# id
# 1        AB10 1XG  57.144156  -2.114864
# 2        AB10 6RN  57.137871  -2.121487
# 3        AB10 7JB  57.124274  -2.127206
# 4        AB11 5QN  57.142701  -2.093295
# 5        AB11 6UL  57.137468  -2.112455
# ...           ...        ...        ...
# 2711464   YO7 4FB  54.243953  -1.472731
# 2711465   YO7 9DN  54.232597  -1.328747
# 2711466   YO8 4FS  53.779924  -1.069318
# 2711467   YO8 6DX  53.809575  -0.923888
# 2711468   ZE2 9FX  60.000038  -1.242494
#
# [1794534 rows x 3 columns]

# %% [markdown]
# # open postcode geo

# %%
odf = pd.read_csv("./open_postcode_geo.csv",
                  header=None,
                  names=["postcode", "status", "usertype", "easting", "northing", "pos_qual", "country", "latitude", "longitude", "nsp", "fxw7", "fxw8", "area", "district", "sector", "inc", "outc"]
                 )

# %%
odf
# Out:
#         postcode      status usertype easting northing  pos_qual   country  \
# 0        AB1 0AA  terminated    small  385386   801193         1  Scotland
# 1        AB1 0AB  terminated    small  385177   801314         1  Scotland
# 2        AB1 0AD  terminated    small  385053   801092         1  Scotland
# 3        AB1 0AE  terminated    small  384600   799300         8  Scotland
# 4        AB1 0AF  terminated    large  384460   800660         8  Scotland
# ...          ...         ...      ...     ...      ...       ...       ...
# 2631531  ZE3 9JW        live    small  438975  1110038         1  Scotland
# 2631532  ZE3 9JX        live    small  438872  1110219         1  Scotland
# 2631533  ZE3 9JY        live    small  438498  1112029         1  Scotland
# 2631534  ZE3 9JZ        live    small  438662  1112122         1  Scotland
# 2631535  ZE3 9XP  terminated    large  438854  1111535         8  Scotland
#
# ...

# %%
odf.to_feather("open_pc_geo.feather")
